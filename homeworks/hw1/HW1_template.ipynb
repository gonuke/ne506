# %% [markdown]
# # Homework Assignment #1

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## A. Direct Continuous Sampling
#
# An experiment indicates that the probability of a scattering event yielding a particular scattering angle varies as the 4th power of the cosine of the angle as
#
# $f(\mu)d\mu = A\cdot \mu^4 d\mu$
#
# for $-1 \le \mu \le 1$, and $A$ is a constant.
#
# Write a function to randomly sample the scattering angle (hint: use the `numpy.power` function in your solution) .
# Plot a histogram for 5,000 samples.

# %% [markdown]
# ## B. Rejection Sampling
#
# Consider a problem where the energy distribution is defined by
#
# $g(e) = AE\sin^2(3\pi E)$
#
# where $0 \le E < 5$ MeV and $A$ is a constant.
#
# 1. Write a function to sample this distribution over the relevant domain.
# 2. Use 2 different bounding functions (only one of which can be a uniform distribution) and compare the empirical efficiency.
# 3. Plot a histogram for the samples from each bounding function.

# %% [markdown]
# ## C. Piecewise Linear
#
# 1. Form a piecewise linear approximation of the function in B using at least 300 points.
# 2. Write a function to sample the piecewise linear distribution.
# 3. Plot a histogram for 5,000 samples.
# 4. Comment on how well the piecewise linear approximation matches the original function
